# %%
import os
import pandas as pd
import numpy as np
from os.path import dirname, abspath

# %%
df = pd.read_csv("C:\\Users\\Preet\\OneDrive\\Desktop\\Intro To ML\\RentPrediction.csv")

# %%
df.head()
# Out:
#          id                                            name host_name  \
# 0   5728806                    Large private room in Nolita       Nat
# 1   2243769              Super Bowl New York City Apartment     Brian
# 2  35515415  COZY APT CLOSE TO LGA & JFK AND TRANSPORTATION     Jenny
# 3  36202006    Stream-Pressed Paradise (Laundry Room Setup)      Rita
# 4   3780951                       Charming Harlem apartment      Gina
#
#   neighbourhood_group    neighbourhood  latitude  longitude        room_type  \
# 0           Manhattan           Nolita  40.72217  -73.99481     Private room
# 1           Manhattan  Upper West Side  40.80020  -73.96045  Entire home/apt
# 2              Queens    East Elmhurst  40.75558  -73.89316  Entire home/apt
# 3       Staten Island          Concord  40.60110  -74.07830      Shared room
# 4           Manhattan           Harlem  40.81022  -73.94266      Shared room
#
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# 0    120               7                  3               0.06
# 1   1500               1                  0                NaN
# 2    200               2                  4               4.00
# 3     30               2                  0                NaN
# 4    115               1                 16               0.27
#
#    calculated_host_listings_count  availability_365
# 0                               3                 0
# 1                               1                 0
# 2                               1               365
# 3                               4                82
# 4                               1               365

# %%
df.tail()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34226 entries, 0 to 34225
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              34226 non-null  int64
#  1   name                            34214 non-null  object
#  2   host_name                       34213 non-null  object
#  3   neighbourhood_group             34226 non-null  object
#  4   neighbourhood                   34226 non-null  object
#  5   latitude                        34226 non-null  float64
#  6   longitude                       34226 non-null  float64
#  7   room_type                       34226 non-null  object
#  8   price                           34226 non-null  int64
#  9   minimum_nights                  34226 non-null  int64
#  10  number_of_reviews               34226 non-null  int64
#  11  reviews_per_month               27244 non-null  float64
#  12  calculated_host_listings_count  34226 non-null  int64
#  13  availability_365                34226 non-null  int64
# dtypes: float64(3), int64(6), object(5)
# memory usage: 3.7+ MB

# %%
df.describe()
# Out:
#                  id      latitude     longitude         price  minimum_nights  \
# count  3.422600e+04  34226.000000  34226.000000  34226.000000    34226.000000
# mean   1.898209e+07     40.729059    -73.952070    153.480979        6.953690
# std    1.097597e+07      0.054604      0.046161    243.312608       20.255833
# min    2.595000e+03     40.499790    -74.244420      0.000000        1.000000
# 25%    9.460366e+06     40.690040    -73.983150     69.000000        1.000000
# 50%    1.965371e+07     40.722995    -73.955700    107.000000        2.000000
# 75%    2.908201e+07     40.763200    -73.935982    175.000000        5.000000
# max    3.648724e+07     40.913060    -73.712990  10000.000000     1250.000000
#
#        number_of_reviews  reviews_per_month  calculated_host_listings_count  \
# count       34226.000000       27244.000000                    34226.000000
# mean           23.390931           1.377074                        7.093905
# std            44.476822           1.688953                       32.828412
# min             0.000000           0.010000                        1.000000
# 25%             1.000000           0.190000                        1.000000
# 50%             5.000000           0.730000                        1.000000
# 75%            24.000000           2.020000                        2.000000
# max           629.000000          58.500000                      327.000000
#
#        availability_365
# count      34226.000000
# mean         113.301730
# std          131.892814
# min            0.000000
# 25%            0.000000
# 50%           45.000000
# 75%          229.000000
# max          365.000000

# %%
df.columns
# Out:
# Index(['id', 'name', 'host_name', 'neighbourhood_group', 'neighbourhood',
#        'latitude', 'longitude', 'room_type', 'price', 'minimum_nights',
#        'number_of_reviews', 'reviews_per_month',
#        'calculated_host_listings_count', 'availability_365'],
#       dtype='object')

# %%
df.shape
# Out:
# (34226, 14)

# %%
df.isnull().sum()

# %%
df['neighbourhood_group'].unique()

# %% [markdown]
# ### There are 5 neighbourhood groups

# %%
df['room_type'].nunique()

# %% [markdown]
# # Column Operations

# %%
#Selection os a column
df[['room_type']]
# Out:
#              room_type
# 0         Private room
# 1      Entire home/apt
# 2      Entire home/apt
# 3          Shared room
# 4          Shared room
# ...                ...
# 34221  Entire home/apt
# 34222     Private room
# 34223  Entire home/apt
# 34224     Private room
# 34225  Entire home/apt
#
# [34226 rows x 1 columns]

# %%
#Making a new column - total listings possible - used during feature engineering process
df['total_listings'] = df['availability_365']/df['minimum_nights']

df.head(10)
# Out:
#          id                                               name host_name  \
# 0   5728806                       Large private room in Nolita       Nat
# 1   2243769                 Super Bowl New York City Apartment     Brian
# 2  35515415     COZY APT CLOSE TO LGA & JFK AND TRANSPORTATION     Jenny
# 3  36202006       Stream-Pressed Paradise (Laundry Room Setup)      Rita
# 4   3780951                          Charming Harlem apartment      Gina
# 5   9944426                             Lower Manhattan Luxury       Dax
# 6  19786915                   Spacious Clean Studio  Apartment    Marian
# 7  22368751  Bright Luxury Apartment with Amazing View of City   Amirhos
# 8  17174519                 Chelsea Brownstone 3 Bedroom House      Wade
# 9  12705519                                      Heights Haven      Drew
#
#   neighbourhood_group       neighbourhood  latitude  longitude  \
# 0           Manhattan              Nolita  40.72217  -73.99481
# 1           Manhattan     Upper West Side  40.80020  -73.96045
# 2              Queens       East Elmhurst  40.75558  -73.89316
# 3       Staten Island             Concord  40.60110  -74.07830
# 4           Manhattan              Harlem  40.81022  -73.94266
# 5           Manhattan   Battery Park City  40.71192  -74.01572
# 6              Queens            Rosedale  40.65766  -73.72838
# 7            Brooklyn         Fort Greene  40.69064  -73.97898
# 8           Manhattan             Chelsea  40.74443  -74.00012
# 9           Manhattan  Washington Heights  40.83170  -73.94290
#
#          room_type  price  minimum_nights  number_of_reviews  \
# 0     Private room    120               7                  3
# 1  Entire home/apt   1500               1                  0
# 2  Entire home/apt    200               2                  4
# 3      Shared room     30               2                  0
# 4      Shared room    115               1                 16
# 5  Entire home/apt    225              90                  1
# 6  Entire home/apt     60               1                 57
# 7  Entire home/apt    200               5                  0
# 8  Entire home/apt    650               3                 35
# 9  Entire home/apt    180              30                  6
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               0.06                               3                 0
# 1                NaN                               1                 0
# 2               4.00                               1               365
# 3                NaN                               4                82
# 4               0.27                               1               365
# 5               0.02                               1               362
# 6               2.41                               1               336
# 7                NaN                               1                 0
# 8               1.61                               2               179
# 9               0.15                               1                 0
#
#    total_listings
# 0        0.000000
# 1        0.000000
# 2      182.500000
# 3       41.000000
# 4      365.000000
# 5        4.022222
# 6      336.000000
# 7        0.000000
# 8       59.666667
# 9        0.000000

# %%
#Deleting a column
df.drop(['total_listings'], axis = 1, inplace = True)

# %%
#Rename a column
df.head()
# Out:
#                  id                                            name  \
# host_name
# Nat         5728806                    Large private room in Nolita
# Brian       2243769              Super Bowl New York City Apartment
# Jenny      35515415  COZY APT CLOSE TO LGA & JFK AND TRANSPORTATION
# Rita       36202006    Stream-Pressed Paradise (Laundry Room Setup)
# Gina        3780951                       Charming Harlem apartment
#
#           neighbourhood_group    neighbourhood  latitude  longitude  \
# host_name
# Nat                 Manhattan           Nolita  40.72217  -73.99481
# Brian               Manhattan  Upper West Side  40.80020  -73.96045
# Jenny                  Queens    East Elmhurst  40.75558  -73.89316
# Rita            Staten Island          Concord  40.60110  -74.07830
# Gina                Manhattan           Harlem  40.81022  -73.94266
#
#                  room_type  price  minimum_nights  number_of_reviews  \
# host_name
# Nat           Private room    120               7                  3
# Brian      Entire home/apt   1500               1                  0
# Jenny      Entire home/apt    200               2                  4
# Rita           Shared room     30               2                  0
# Gina           Shared room    115               1                 16
#
#            reviews_per_month  calculated_host_listings_count  availability_365
# host_name
# Nat                     0.06                               3                 0
# Brian                    NaN                               1                 0
# Jenny                   4.00                               1               365
# Rita                     NaN                               4                82
# Gina                    0.27                               1               365

# %% [markdown]
# # Row Operations

# %%
#Locating a row
df.set_index('host_name', inplace = True)
#df.loc['Brian']     #index

#Locate using row number
#df.iloc[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16936\3479007188.py in ?()
#       1 #Locating a row
# ----> 2 df.set_index('host_name', inplace = True)
#       3
#       4 df.loc['Jenny']
#       5
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5855                     if not found:
#    5856                         missing.append(col)
#    5857
#    5858         if missing:
# -> 5859             raise KeyError(f"None of {missing} are in the columns")
#    5860
#    5861         if inplace:
#    5862             frame = self
#
# KeyError: "None of ['host_name'] are in the columns"

# %%
df.head()
# Out:
#                  id                                            name  \
# host_name
# Nat         5728806                    Large private room in Nolita
# Brian       2243769              Super Bowl New York City Apartment
# Jenny      35515415  COZY APT CLOSE TO LGA & JFK AND TRANSPORTATION
# Rita       36202006    Stream-Pressed Paradise (Laundry Room Setup)
# Gina        3780951                       Charming Harlem apartment
#
#           neighbourhood_group    neighbourhood  latitude  longitude  \
# host_name
# Nat                 Manhattan           Nolita  40.72217  -73.99481
# Brian               Manhattan  Upper West Side  40.80020  -73.96045
# Jenny                  Queens    East Elmhurst  40.75558  -73.89316
# Rita            Staten Island          Concord  40.60110  -74.07830
# Gina                Manhattan           Harlem  40.81022  -73.94266
#
#                  room_type  price  minimum_nights  number_of_reviews  \
# host_name
# Nat           Private room    120               7                  3
# Brian      Entire home/apt   1500               1                  0
# Jenny      Entire home/apt    200               2                  4
# Rita           Shared room     30               2                  0
# Gina           Shared room    115               1                 16
#
#            reviews_per_month  calculated_host_listings_count  availability_365
# host_name
# Nat                     0.06                               3                 0
# Brian                    NaN                               1                 0
# Jenny                   4.00                               1               365
# Rita                     NaN                               4                82
# Jenny               Manhattan            Lower East Side  40.71812  -73.98619
# Jenny               Manhattan                  Chinatown  40.71463  -73.99216
# Jenny               Manhattan                    Tribeca  40.71206  -74.00999
# Jenny                  Queens                  Ridgewood  40.71032  -73.91461
# Jenny                Brooklyn                Cobble Hill  40.68849  -73.99560
# Jenny                Brooklyn  Prospect-Lefferts Gardens  40.66025  -73.96270
# Jenny                Brooklyn         Bedford-Stuyvesant  40.69013  -73.92805
# Jenny               Manhattan          Greenwich Village  40.72893  -74.00176
# Jenny                Brooklyn               Williamsburg  40.70710  -73.94634
# Jenny               Manhattan                     Harlem  40.81070  -73.94731
# Jenny                  Queens               Forest Hills  40.71818  -73.84944
# Jenny               Manhattan                       NoHo  40.72591  -73.99452
# Jenny               Manhattan             Hell's Kitchen  40.76097  -74.00026
#
#                  room_type  price  minimum_nights  number_of_reviews  \
# host_name
# Nat           Private room    120               7                  3
# Nat           Private room     69               2                 16
# Nat           Private room     80               3                  0
# Nat        Entire home/apt    100               2                  8
# Nat           Private room     70               1                  0
# Nat        Entire home/apt     85               5                 42
# Jenny      Entire home/apt    200               2                  4
# Jenny      Entire home/apt    375               2                 40
# Jenny      Entire home/apt    135               3                  0
# Jenny         Private room     40               2                  4
# Jenny         Private room    115               2                 72
# Jenny         Private room    100               5                204
# Jenny         Private room     69               4                 34
# Jenny         Private room     47               1                  4
# Jenny      Entire home/apt     50               1                  0
# Jenny      Entire home/apt    205               3                102
# Jenny      Entire home/apt    209               1                  0
# Jenny      Entire home/apt     50               1                  2
# Jenny         Private room     55               3                 66
# Jenny         Private room     48               5                  3
# Jenny         Private room     58               5                  0
# Jenny      Entire home/apt    189               3                173
# Jenny      Entire home/apt    225               4                  7
# Jenny          Shared room     40              22                  1
# Jenny      Entire home/apt    135               3                 18
# Jenny      Entire home/apt     88               2                 13
# Jenny         Private room     55              91                  0
# Jenny      Entire home/apt   1497               1                 10
# Jenny         Private room    124               1                  5
# Jenny         Private room     39               4                 33
# Jenny         Private room     53               3                  1
# Jenny      Entire home/apt    173               2                  3
# Jenny      Entire home/apt    150               1                 14
# Jenny         Private room     65               4                 26
# Jenny         Private room     50              10                  4
# Jenny      Entire home/apt    239               1                272
# Jenny         Private room    139               4                 14
# Jenny         Private room     50               3                 61
# Jenny         Private room     60               1                  3
# Jenny         Private room     45               5                  3
# Jenny         Private room     80              31                 28
# Jenny      Entire home/apt    197               1                285
# Jenny         Private room    100               2                  1
# Jenny      Entire home/apt   6500             180                  0
# Jenny         Private room     69               7                  0
# Jenny      Entire home/apt    125               2                137
# Jenny      Entire home/apt    120               3                  3
# Jenny      Entire home/apt    215               1                167
# Jenny      Entire home/apt    205               3                  2
# Jenny         Private room     65               5                  1
# Jenny      Entire home/apt    150               2                 10
# Jenny         Private room    109               1                 86
# Jenny      Entire home/apt    465              30                 47
# Jenny      Entire home/apt    135               1                  1
#
#            reviews_per_month  calculated_host_listings_count  availability_365
# host_name
# Nat                     0.06                               3                 0
# Nat                     1.07                               2               185
# Nat                      NaN                               1                 0
# Nat                     0.17                               1               359
# Nat                      NaN                               1                 0
# Nat                     1.27                               1                52
# Jenny                   4.00                               1               365
# Jenny                   1.54                               2               285
# Jenny                    NaN                               1               227
# Jenny                   0.18                               1                 0
# Jenny                   2.55                               2               275
# Jenny                   1.92                               1               192
# Jenny                   0.72                               3                68
# Jenny                   0.15                               1                 0
# Jenny                    NaN                               2                 0
# Jenny                   3.36                               1               117
# Jenny                    NaN                               2               112
# Jenny                   0.10                               2                 0
# Jenny                   1.16                               3               264
# Jenny                   0.06                               1                 0
# Jenny                    NaN                               1               180
# Jenny                   2.36                               1               265
# Jenny                   0.19                               1                 0
# Jenny                   1.00                               1                12
# Jenny                   2.19                               1               307
# Jenny                   0.37                               1                 0
# Jenny                    NaN                               1               364
# Jenny                   2.36                               1               363
# Jenny                   0.20                               2               111
# Jenny                   4.36                               1                86
# Jenny                   0.06                               1                 0
# Jenny                   0.13                               1                 0
# Jenny                   1.17                               1                 0
# Jenny                   0.85                               2                 7
# Jenny                   0.25                               1                 0
# Jenny                   5.98                               1               305
# Jenny                   1.75                               1                28
# Jenny                   2.17                               2                22
# Jenny                   3.00                               2               178
# Jenny                   0.16                               1                 0
# Jenny                   0.40                               1               167
# Jenny                   4.83                               1                 8
# Jenny                   0.08                               1                 0
# Jenny                    NaN                               1               365
# Jenny                    NaN                               1                 0
# Jenny                   5.78                               1                 2
# Jenny                   0.05                               1                16
# Jenny                   2.86                               1               250
# Jenny                   0.05                               1                 0
# Jenny                   0.39                               1                35
# Jenny                   0.49                               1                 0
# Jenny                   1.78                               1               344
# Jenny                   0.67                               1               277
# Jenny                   1.00                               1                 9

# %%
#Locate using row number
df.iloc[1]
# Out:
# id                                                           2243769
# name                              Super Bowl New York City Apartment
# neighbourhood_group                                        Manhattan
# neighbourhood                                        Upper West Side
# latitude                                                     40.8002
# longitude                                                  -73.96045
# room_type                                            Entire home/apt
# price                                                           1500
# minimum_nights                                                     1
# number_of_reviews                                                  0
# reviews_per_month                                                NaN
# calculated_host_listings_count                                     1
# availability_365                                                   0
# Name: Brian, dtype: object

# %%
#Function to find total values in each category
df['neighbourhood_group'].value_counts()
# Out:
# neighbourhood_group
# Manhattan        15193
# Brooklyn         14033
# Queens            3985
# Bronx              767
# Staten Island      248
# Name: count, dtype: int64

# %%
#Conditional filtering - view only the data from Bronx neighbourhood group
bronx = df[df['neighbourhood_group'] == 'Bronx']

# %%
#Conditional filtering - View houses from Manhattan whose price is 1500
df[(df['neighbourhood_group'] == 'Bronx') & (df['price'] > 175) & (df['minimum_nights'] == 1)]
# Out:
#                  id                                              name  \
# host_name
# Deon       26147702                              YANKEE BASEBALL STAY
# Buddy      36177241                            VJ'S 5 HOUR YACHT TOUR
# Linda      29205007                                    Parkside Place
# Marisol     9412522                City living without all the noise.
# Andy       22179180  5 ★★★★★ Gorgeous suite only 1 block from subway!
# Deon       26142708                              Yankee baseball stay
# Aaron      28522394                                          The Spot
# Tyeesha    28867880                                   Convenient stay
# Quisqueya  23613688           Clean Spacious Duplex by Yankee Stadium
# Andy       30948025          ⭐️ Luxury Studio with modern finishes ⭐️
# Angelie    30253236                              SedaOn2 Dance Studio
# Andy       30948241    Book NOW this New 3br Home with lots of space.
#
#           neighbourhood_group       neighbourhood  latitude  longitude  \
# host_name
# Deon                    Bronx           Concourse  40.82714  -73.92528
# Buddy                   Bronx         City Island  40.84443  -73.78497
# Linda                   Bronx             Norwood  40.87448  -73.87412
# Marisol                 Bronx         Kingsbridge  40.87900  -73.90062
# Andy                    Bronx      Williamsbridge  40.87850  -73.86347
# Deon                    Bronx           Concourse  40.82753  -73.92463
# Aaron                   Bronx            Van Nest  40.83988  -73.86978
# Tyeesha                 Bronx      Morris Heights  40.85324  -73.92143
# Quisqueya               Bronx          Highbridge  40.83604  -73.93099
# Andy                    Bronx      Williamsbridge  40.87701  -73.86282
# Angelie                 Bronx  Westchester Square  40.84378  -73.84469
# Andy                    Bronx             Belmont  40.85222  -73.89277
#
#                  room_type  price  minimum_nights  number_of_reviews  \
# host_name
# Deon          Private room    200               1                  0
# Buddy      Entire home/apt   1000               1                  0
# Linda      Entire home/apt    200               1                 13
# Marisol    Entire home/apt    189               1                  8
# Andy       Entire home/apt    200               1                 90
# Deon          Private room    200               1                  0
# Aaron      Entire home/apt    300               1                  0
# Tyeesha       Private room    240               1                  0
# Quisqueya  Entire home/apt    240               1                 22
# Andy       Entire home/apt    200               1                 34
# Angelie    Entire home/apt    670               1                  2
# Andy       Entire home/apt    299               1                 10
#
#            reviews_per_month  calculated_host_listings_count  availability_365
# host_name
# Deon                     NaN                               2               179
# Buddy                    NaN                               4                90
# Linda                   6.61                               1                 0
# Marisol                 0.22                               2               354
# Andy                    4.76                               3               326
# Deon                     NaN                               2               365
# Aaron                    NaN                               1               365
# Tyeesha                  NaN                               1               363
# Quisqueya               1.40                               3                 1
# Andy                    5.13                               3               347
# Angelie                 0.34                               1               178
# Andy                    1.52                               3               322

# %%
#Apply function - to change 'Entire home/apt' to 'Entire home'

df['room_type'] = df['room_type'].apply(lambda x: x.strip('/apt'))

# %%
def square(x):
    return x**2

# %%
df['minimum_nights'].apply(square)
# Out:
# host_name
# Nat          49
# Brian         1
# Jenny         4
# Rita          4
# Gina          1
#              ..
# Sophie       25
# Gabi          1
# Mary          4
# Olu Bliss     9
# Ashton       16
# Name: minimum_nights, Length: 34226, dtype: int64

# %%
#Groupby function - to find the mean prices for each neighbourhood group
df.groupby('neighbourhood_group')[['price']].mean().sort_values(by = 'price', ascending = True)
# Out:
#                           price
# neighbourhood_group
# Bronx                 88.146023
# Queens                98.661731
# Staten Island        118.491935
# Brooklyn             125.868880
# Manhattan            197.233002
